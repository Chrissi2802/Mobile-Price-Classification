# %% [markdown]
# # Machine learning (ML)

# %%
import pandas as pd
import yaml
import sys
sys.path.append("..")

from src.data import MP_Dataset
from src.train import MP_Models
from src.prediction import MP_Prediction

# %% [markdown]
# ## Information

# %%
with open("../info.yaml", "r") as yaml_file:
    yaml_data = yaml.safe_load(yaml_file)

dict_params_user = yaml_data["dict_params_user"]

# %% [markdown]
# ## Data

# %%
MPD = MP_Dataset(dict_params_user["prefix"])

# %%
dict_data = MPD.get_data()
dict_data.keys()
# Out:
# dict_keys(['description', 'train', 'train_x', 'train_fe', 'train_fe_x', 'train_y', 'test', 'test_x', 'test_fe', 'test_fe_x', 'test_y'])

# %% [markdown]
# ## Training

# %%
MPM = MP_Models(dict_data, dict_params_user)
# Out:
# Model: LogisticRegression
#    No hyperparameters for the LogisticRegression model were found in mlflow!
#    Search the best hyperparameters for the LogisticRegression model.
#    Train and evaluate the LogisticRegression model.
# 2023/11/08 17:00:38 INFO mlflow.tracking.fluent: Experiment with name 'Mobile Price Classification' does not exist. Creating a new experiment.
# Model: RandomForestClassifier
#    No hyperparameters for the RandomForestClassifier model were found in mlflow!
#    Search the best hyperparameters for the RandomForestClassifier model.
#    Train and evaluate the RandomForestClassifier model.
#
# Model: XGBClassifier
#    No hyperparameters for the XGBClassifier model were found in mlflow!
#    Search the best hyperparameters for the XGBClassifier model.
#    Train and evaluate the XGBClassifier model.

# %% [markdown]
# ## Prediction

# %%
columns = dict_data["train_x"].columns

# Test data --> 1
df = pd.DataFrame(
    [[842.0, 0.0, 2.2, 0.0, 1.0, 0.0, 7.0, 0.6, 188.0, 2.0, 2.0, 20.0, 756.0, 2549.0, 9.0, 7.0, 19.0, 0.0, 0.0, 1.0]],
    columns=columns,
)

# %%
MPP = MP_Prediction(dict_params_user)

# %%
pred = MPP.predict(df)
pred
# Out:
# {'pred': array([1], dtype=int64),
#  'pred_proba': array([[5.96802648e-04, 9.52000970e-01, 4.74022236e-02, 4.18221952e-09]])}
